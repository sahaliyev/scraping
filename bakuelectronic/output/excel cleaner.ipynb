# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('smartfonlar-mobil-telefonlar.xlsx')

# %%
parsed_df = df[df['parsed'] == 1]

# %%
parsed_df
# Out:
#                                                 title  \
# 0     Smartfon Samsung Galaxy S21 128GB Violet (G991)
# 1      Smartfon Samsung Galaxy A32 4/64GB Blue (A325)
# 2    Smartfon Samsung Galaxy A32 4/64GB Violet (A325)
# 3     Smartfon Samsung Galaxy A32 4/64GB Black (A325)
# 5      Smartfon Xiaomi Redmi Note 9 128GB White (NFC)
# ..                                                ...
# 104       Smartfon Samsung Galaxy A12 32GB Red (A125)
# 105     Smartfon Samsung Galaxy A12 32GB Black (A125)
# 107     Smartfon Samsung Galaxy A12 64GB Black (A125)
# 108              Smartfon Xiaomi Poco M3 4/128GB BLUE
# 109                Smartfon Huawei P Smart 2021 BLACK
#
#                                                  image  \
# 0    https://www.bakuelectronics.az/assets/cache_im...
# 1    https://www.bakuelectronics.az/assets/cache_im...
# 2    https://www.bakuelectronics.az/assets/cache_im...
# 3    https://www.bakuelectronics.az/assets/cache_im...
# ...

# %%
parsed_df.to_excel('new_smartfonlar-mobil-telefonlar.xlsx')

# %%
parsed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 109
# Data columns (total 42 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   title                                        100 non-null    object
#  1   image                                        100 non-null    object
#  2   url                                          100 non-null    object
#  3   Brend:                                       100 non-null    object
#  4   Məhsul tipi:                                 89 non-null     object
#  5   Şəbəkə:                                      88 non-null     object
#  6   SIM-kart sayı:                               93 non-null     object
#  7   SIM-kart ölçüsü:                             89 non-null     object
#  8   Ekranın ölçüsü:                              89 non-null     object
# ...
